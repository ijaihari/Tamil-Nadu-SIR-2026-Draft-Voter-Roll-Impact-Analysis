# %% [markdown]
# # Tamil Nadu SIR — Voter Roll Revision Impact Analysis (Final Analysis)
#
# ## Objective
# This notebook performs the **core analytical step** of the project.
#
# The goal is to evaluate whether **voter roll revisions under Tamil Nadu SIR (2025)** are large enough to **numerically affect election outcomes**, using **victory margin** from the 2021 Assembly Election as the sensitivity threshold.
#
# This is a **data-driven impact analysis**, not an allegation-based study.

# %% [markdown]
# ## Analytical Framework
#
# The analysis is built on three concepts:
#
# 1. **Victory Margin (2021)**
#    - Minimum number of votes required to change an election outcome.
#    - Used as the primary sensitivity threshold.
#
# 2. **Not Voted (2021)**
#    - Represents historical voter inactivity.
#    - Used as a baseline to contextualize voter removals.
#
# 3. **Removed Voters (2025)**
#    - Structural change introduced by SIR voter roll revision.
#
# ### Core Question:
# > Are voter roll changes larger than the margin that decided the election?

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../db/tn_election.db")

# %% [markdown]
# ## Load Curated Tables
#
# The following pre-processed tables are loaded from SQLite:
#
# - `election_results_2021` → victory margin & parties
# - `voters_2021` → turnout & not voted baseline
# - `voters_2025` → revised voter roll (SIR 2025)

# %%
df_results_2021 = pd.read_sql("SELECT * FROM election_results_2021", conn)

df_voters_2021 = pd.read_sql("SELECT * FROM voters_2021", conn)

df_voters_2025 = pd.read_sql("SELECT * FROM voters_2025", conn)

# %% [markdown]
# ## Compare Voter Rolls (2021 vs 2025)
#
# This step aligns the voter rolls by constituency and computes
# the **net change in eligible voters**.
#
# A positive value indicates **voters removed**.

# %%
df_roll_compare = (
    df_voters_2021
    .merge(
        df_voters_2025,
        on=["ac_no", "ac_name"],
        how="inner"
    )
)

df_roll_compare["removed_voters_2025"] = (
    df_roll_compare["total_eligible_voters_2021"]
    - df_roll_compare["total_eligible_voters_2025"]
)

df_roll_compare
# Out:
#      ac_no          ac_name  total_votes_polled_2021  \
# 0        1    Gummidipoondi                   222069
# 1        2          Ponneri                   210354
# 2        3        Tiruttani                   232624
# 3        4      Thiruvallur                   214243
# 4        5      Poonamallee                   263736
# ..     ...              ...                      ...
# 227    230        Nagercoil                   184185
# 228    231         Colachal                   182969
# 229    232  Padmanabhapuram                   170156
# 230    233      Vilavancode                   167836
# 231    234        Killiyoor                   169918
#
#      total_eligible_voters_2021  not_voted_2021  total_eligible_voters_2025  \
# 0                        281688           59619                      242558
# 1                        267368           57014                      239141
# 2                        291336           58712                      252154
# 3                        274982           60739                      238818
# 4                        358218           94482                      348034
# ..                          ...             ...                         ...
# 227                      270845           86660                      243329
# 228                      269287           86318                      251388
# 229                      240853           70697                      224140
# 230                      250065           82229                      214360
# 231                      255347           85429                      232213
#
#      removed_voters_2025
# 0                  39130
# 1                  28227
# 2                  39182
# 3                  36164
# 4                  10184
# ..                   ...
# 227                27516
# 228                17899
# 229                16713
# 230                35705
# 231                23134
#
# [232 rows x 7 columns]

# %% [markdown]
# ## Attach Election Outcome Data
#
# Victory margin from the 2021 election is now joined with
# voter roll changes to assess **outcome sensitivity**.

# %%
df_analysis = (
    df_results_2021
    .merge(
        df_roll_compare,
        on=["ac_no", "ac_name"],
        how="inner"
    )
)

df_analysis
# Out:
#      ac_no          ac_name winner_party  votes_winner runnerup_party  \
# 0        1    Gummidipoondi          DMK        126452            PMK
# 1        2          Ponneri          INC         94528           ADMK
# 2        3        Tiruttani          DMK        120314           ADMK
# 3        4      Thiruvallur          DMK        107709           ADMK
# 4        5      Poonamallee          DMK        149578            PMK
# ..     ...              ...          ...           ...            ...
# 227    230        Nagercoil          BJP         88804            DMK
# 228    231         Colachal          INC         90681            BJP
# 229    232  Padmanabhapuram          DMK         87744           ADMK
# 230    233      Vilavancode          INC         87473            BJP
# 231    234        Killiyoor          INC        101541           ADMK
#
#      votes_runnerup  victory_margin  total_votes_polled_2021  \
# 0             75514           50938                   222069
# 1             84839            9689                   210354
# 2             91061           29253                   232624
# 3             85008           22701                   214243
# 4             55468           94110                   263736
# ..              ...             ...                      ...
# 227           77135           11669                   184185
# 228           65849           24832                   182969
# 229           60859           26885                   170156
# 230           58804           28669                   167836
# 231           46141           55400                   169918
#
#      total_eligible_voters_2021  not_voted_2021  total_eligible_voters_2025  \
# 0                        281688           59619                      242558
# 1                        267368           57014                      239141
# 2                        291336           58712                      252154
# 3                        274982           60739                      238818
# 4                        358218           94482                      348034
# ..                          ...             ...                         ...
# 227                      270845           86660                      243329
# 228                      269287           86318                      251388
# 229                      240853           70697                      224140
# 230                      250065           82229                      214360
# 231                      255347           85429                      232213
#
#      removed_voters_2025
# 0                  39130
# 1                  28227
# 2                  39182
# 3                  36164
# 4                  10184
# ..                   ...
# 227                27516
# 228                17899
# 229                16713
# 230                35705
# 231                23134
#
# [232 rows x 12 columns]

# %% [markdown]
# ## Core Impact Tests
#
# Two key comparisons are performed:
#
# 1. **Removed Voters vs Victory Margin**
#    - Determines if roll changes exceed the threshold that decided the election.
#
# 2. **Removed Voters vs Not Voted (2021)**
#    - Provides historical inactivity context.

# %%
df_analysis["removed_gt_margin"] = (
    df_analysis["removed_voters_2025"] > df_analysis["victory_margin"]
)

df_analysis["removed_gt_not_voted"] = (
    df_analysis["removed_voters_2025"] > df_analysis["not_voted_2021"]
)

# %% [markdown]
# ## Risk Classification
#
# Each constituency is classified based on the magnitude of
# voter roll change relative to:
#
# - victory margin
# - historical non-participation
#
# This creates a **numerical risk categorization**, not a judgement.

# %%
def classify_risk(row):
    if row["removed_voters_2025"] <= 0:
        return "No Removal / Increase"
    if row["removed_gt_margin"] and row["removed_gt_not_voted"]:
        return "Critical Impact"
    if row["removed_gt_margin"]:
        return "High Impact"
    if row["removed_gt_not_voted"]:
        return "Moderate Impact"
    return "Low Impact"

df_analysis["risk_level"] = df_analysis.apply(classify_risk, axis=1)

# %% [markdown]
# ## Final Analytical Dataset
#
# This table represents the **final output** of the project
# and is used for reporting, visualization, and SQL storage.

# %%
df_final_analysis = df_analysis[
    [
        "ac_no",
        "ac_name",
        "winner_party",
        "runnerup_party",
        "victory_margin",
        "total_eligible_voters_2021",
        "total_eligible_voters_2025",
        "removed_voters_2025",
        "not_voted_2021",
        "risk_level"
    ]
].sort_values(
    "removed_voters_2025",
    ascending=False
)

df_final_analysis
# Out:
#      ac_no          ac_name winner_party runnerup_party  victory_margin  \
# 26      27  Shozhinganallur          DMK           ADMK           35405
# 29      30       Pallavaram          DMK           ADMK           37783
# 6        7      Maduravoyal          DMK           ADMK           31721
# 25      26        Velachery          INC           ADMK            4352
# 20      21       Anna Nagar          DMK           ADMK           27445
# ..     ...              ...          ...            ...             ...
# 56      58       Pennagaram          PMK            DMK           21186
# 208    211   Ramanathapuram          DMK            BJP           50312
# 74      77    Ulundurpettai          DMK           ADMK            5256
# 75      78    Rishivandiyam          DMK           ADMK           41728
# 28      29    Sriperumbudur          INC           ADMK           10879
#
#      total_eligible_voters_2021  total_eligible_voters_2025  \
# 26                       698893                      484011
# 29                       436239                      294712
# 6                        452195                      325407
# 25                       314578                      189999
# 20                       286090                      162135
# ..                          ...                         ...
# 56                       246772                      239492
# 208                      308443                      301987
# 74                       293464                      287413
# 75                       268323                      262564
# 28                       355267                      355316
#
#      removed_voters_2025  not_voted_2021             risk_level
# 26                214882          310538            High Impact
# 29                141527          170049            High Impact
# 6                 126788          178325            High Impact
# 25                124579          137864            High Impact
# 20                123955          120994        Critical Impact
# ..                   ...             ...                    ...
# 56                  7280           36467             Low Impact
# 208                 6456           94345             Low Impact
# 74                  6051           48611            High Impact
# 75                  5759           53217             Low Impact
# 28                   -49           91005  No Removal / Increase
#
# [232 rows x 10 columns]

# %% [markdown]
# ## Key Insights
#
# - Constituencies where **removed voters exceed victory margin**
#   are numerically sensitive to roll revisions.
#
# - Comparing removals with **not voted (2021)** prevents misleading conclusions.
#
# - The analysis highlights **outcome sensitivity**, not intent.

# %%
df_final_analysis.to_sql(
    "voter_roll_impact_analysis",
    conn,
    if_exists="replace",
    index=False
)
# Out:
# 232

# %% [markdown]
# ## Visual Impact Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. Victory Margin vs Removed Voters (Core Sensitivity Plot)
#
# This scatter plot visualizes whether voter roll changes
# exceed the margin that decided the 2021 election.
#
# - X-axis: Victory Margin (2021)
# - Y-axis: Removed Voters (2025)
# - Points above the horizontal axis indicate voter removal
#
# Constituencies where removed voters exceed the victory margin
# are numerically sensitive to roll revisions.

# %%
plt.figure(figsize=(10, 6))

plt.scatter(
    df_final_analysis["victory_margin"],
    df_final_analysis["removed_voters_2025"],
    alpha=0.6
)

plt.axhline(y=0)
plt.xlabel("Victory Margin (2021)")
plt.ylabel("Removed Voters (2025)")
plt.title("Victory Margin vs Removed Voters (SIR 2025 Impact)")

plt.show()
